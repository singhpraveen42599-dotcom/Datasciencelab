# %% [markdown]
# <a href="https://colab.research.google.com/github/singhpraveen42599-dotcom/Datasciencelab/blob/main/BCSE1593_Data_Loading_Storage_File_Formats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BCSE 1593 – Data Science and Visualization Lab
#
# ## Practicals based on Data Loading, Storage and File Formats
#
# In the previous practical, we worked with pandas data structures such as **Series, DataFrame and Index**.
#
# Now we will use those structures with data stored in different files and locations.
#
# A real data analyst rarely creates a complete dataset inside Python. Usually, the data already exists in a file or is available at a data source.
#
# In this practical, we will learn how to:
#
# - load data from CSV files
# - load delimited text files
# - load JSON data
# - load Excel files
# - load data from a URL
# - work with file paths
# - save pandas data to different formats
# - read saved files back into pandas
# - understand text and binary data formats
# - choose a suitable file format for a task
#
# The main idea is:
#
# > **Load → inspect → work with the data → store it in a suitable format**
#
# The later practicals will deal separately with web APIs, data cleaning, data wrangling, visualization, aggregation and time-series analysis. Those topics are not the focus here.

# %% [markdown]
# # Part A – Getting Started
#
# ## 1. Importing pandas
#
# We will use pandas for loading and storing tabular data.
#
# The standard convention is to use the alias `pd`.
#
# ### Live coding
#
# Import pandas using the standard alias.
#
# Keep the command simple.

# %%
print("Importing pandas")
# Write the import statement here
import pandas as pd
# Out:
# Importing pandas

# %% [markdown]
# ## 2. File formats in data science
#
# Different types of files are commonly used for storing data.
#
# | Format | Common extension | Typical use |
# |---|---|---|
# | CSV | `.csv` | tabular data, very common |
# | TSV / delimited text | `.tsv`, `.txt` | tabular text with another separator |
# | JSON | `.json` | structured and nested data |
# | Excel | `.xlsx` | spreadsheets and business data |
# | Pickle | `.pkl` | storing Python objects |
# | Parquet | `.parquet` | efficient analytical data storage |
#
# There is no single "best" format for every situation.
#
# For example:
#
# - CSV is simple and widely supported.
# - Excel is convenient for spreadsheet users.
# - JSON is useful for structured records and nested data.
# - Pickle can preserve Python objects.
# - Parquet is designed for efficient analytical workloads.
#
# In this practical, we will focus on formats that can be used comfortably with pandas.

# %% [markdown]
# ## 3. File path and file location
#
# When pandas loads a local file, it needs to know where the file is located.
#
# For example:
#
# ```text
# train.csv
# ```
#
# means the file is expected in the current working directory.
#
# A path can also look like:
#
# ```text
# data/train.csv
# ```
#
# or, on Windows:
#
# ```text
# data\\train.csv
# ```
#
# A path is different from the **data itself**. It tells Python where to find the data.

# %% [markdown]
# ## 4. Checking the current working directory
#
# Python has a current working directory.
#
# Knowing it can help when a file cannot be found.
#
# ### Live coding
#
# Use Python's `os` module to display the current working directory.
#
# The `print()` statement is already provided.

# %%
import os
print("Current working directory:")
# Write the expression that displays the current working directory
print(os.getcwd())
# Out:
# Current working directory:
# /content

# %% [markdown]
# ## 5. Looking at files in the current directory
#
# Python can also show the files and folders available in the current working directory.
#
# ### Live coding
#
# Display the contents of the current working directory.
#
# This is useful when you are not sure whether a file has been uploaded correctly.

# %%
print("Files and folders:")
# Write the expression that lists the current directory
print(os.listdir())
# Out:
# Files and folders:
# ['.config', 'sample_data']

# %% [markdown]
# # Part B – CSV Files
#
# ## 6. Why CSV?
#
# CSV stands for **Comma-Separated Values**.
#
# A simple CSV file may look like:
#
# ```text
# Name,Department,Salary
# Aman,IT,55000
# Priya,HR,48000
# Kunal,Sales,62000
# ```
#
# CSV is a text format.
#
# It is one of the most commonly used formats for tabular data because it is:
#
# - simple
# - readable
# - supported by many tools
# - easy to exchange between systems
#
# Pandas provides `read_csv()` for loading CSV data.

# %% [markdown]
# ## 7. Loading a local CSV file
#
# Suppose a file named `employees.csv` is present in the current folder.
#
# The basic idea is:
#
# ```text
# read a CSV file → receive a DataFrame
# ```
#
# ### Live coding
#
# Write the pandas command to load `employees.csv` into a DataFrame called `employees`.
#
# Then display the DataFrame.
#
# Do not create the DataFrame manually.

# %%
import pandas as pd
from pathlib import Path

print("Loading employees.csv")

# Create a dummy employees.csv file for demonstration
csv_content = """Name,Department,Salary\nAman,IT,55000\nPriya,HR,48000\nKunal,Sales,62000\n"""
Path("employees.csv").write_text(csv_content)
print("Created dummy employees.csv")

# Load the CSV file into a DataFrame
employees=pd.read_csv("employees.csv")
# Display the DataFrame
print(employees)
# Out:
# Loading employees.csv
# Created dummy employees.csv
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 8. Checking a loaded CSV file
#
# After loading data, we should first confirm that it was loaded correctly.
#
# Useful checks include:
#
# - shape
# - column names
# - data types
# - first few rows
# - last few rows
#
# These are inspection steps. We are not cleaning or changing the data here.
#
# ### Live coding
#
# Using `employees`, display:
#
# 1. shape
# 2. column names
# 3. data types
# 4. first five rows

# %%
print("Shape:")
# Write the expression
print(employees.shape)
print("Columns:")
# Write the expression
print(employees.columns)
print("Data types:")
# Write the expression
print(employees.dtypes)
print("First five rows:")
# Write the expression
print(employees.head())
# Out:
# Shape:
# (3, 3)
# Columns:
# Index(['Name', 'Department', 'Salary'], dtype='object')
# Data types:
# Name          object
# Department    object
# Salary         int64
# dtype: object
# First five rows:
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 9. CSV with a different separator
#
# Not every text file uses commas.
#
# For example:
#
# ```text
# Name|Department|Salary
# Aman|IT|55000
# Priya|HR|48000
# ```
#
# Here the separator is `|`.
#
# `read_csv()` allows us to specify the separator.
#
# ### Live coding
#
# Suppose `employees_pipe.txt` contains data separated by `|`.
#
# Load it into a DataFrame called `employees_pipe`.
#
# Use the appropriate argument of `read_csv()`.

# %%
from pathlib import Path

print("Loading pipe-separated data:")
# Create a dummy employees_pipe.txt file for demonstration
pipe_content = """Name|Department|Salary\nAman|IT|55000\nPriya|HR|48000\nKunal|Sales|62000\n"""
Path("employees_pipe.txt").write_text(pipe_content)
print("Created dummy employees_pipe.txt")

# Load employees_pipe.txt using the correct separator
employees_pipe=pd.read_csv("employees_pipe.txt",sep="|")
# Display the DataFrame
print(employees_pipe)
# Out:
# Loading pipe-separated data:
# Created dummy employees_pipe.txt
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 10. TSV files
#
# TSV means **Tab-Separated Values**.
#
# Example:
#
# ```text
# Name    Department    Salary
# Aman    IT            55000
# Priya   HR            48000
# ```
#
# The separator is a tab character.
#
# Pandas can read TSV data by using `read_csv()` with the appropriate separator.
#
# ### Live coding
#
# Load `employees.tsv` into a DataFrame called `employees_tsv`.
#
# Use the tab separator.

# %%
from pathlib import Path

print("Loading TSV data:")
# Create a dummy employees.tsv file for demonstration
tsv_content = "Name\tDepartment\tSalary\nAman\tIT\t55000\nPriya\tHR\t48000\nKunal\tSales\t62000\n"
Path("employees.tsv").write_text(tsv_content)
print("Created dummy employees.tsv")

# Load the TSV file
employees_tsv=pd.read_csv("employees.tsv",sep="\t")
# Display the DataFrame
print(employees_tsv)
# Out:
# Loading TSV data:
# Created dummy employees.tsv
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 11. Useful `read_csv()` options
#
# `read_csv()` has many options.
#
# Some useful ones include:
#
# | Option | Purpose |
# |---|---|
# | `sep` | specify the separator |
# | `header` | identify the header row |
# | `names` | provide column names |
# | `index_col` | use a column as the index |
# | `usecols` | load selected columns |
# | `nrows` | load a limited number of rows |
# | `skiprows` | skip rows |
#
# You do not need to memorise every option. The important skill is knowing that the function can be adjusted when a file does not follow the default CSV structure.

# %% [markdown]
# ## 12. Loading selected columns
#
# Suppose a large CSV contains many columns, but the analyst only needs:
#
# - Name
# - Department
# - Salary
#
# `read_csv()` can load selected columns instead of loading everything.
#
# ### Live coding
#
# Load only these three columns from `employees.csv` into `employees_small`.
#
# Use the appropriate `read_csv()` argument.

# %%
print("Selected columns:")
# Load only Name, Department and Salary
employees_small=pd.read_csv("employees.csv",usecols=["Name","Department","Salary"])
# Display the DataFrame
print(employees_small)
# Out:
# Selected columns:
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 13. Loading a limited number of rows
#
# Sometimes we want to inspect only a small part of a large file.
#
# `read_csv()` can load a specified number of rows.
#
# ### Live coding
#
# Load only the first 5 rows of `employees.csv` into `employee_sample`.

# %%
print("First five records:")
# Load only the first 5 rows
print(pd.read_csv("employees.csv",nrows=5))
# Out:
# First five records:
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# # Part C – Loading Data from a URL
#
# ## 14. Local file vs URL
#
# Data does not always have to be downloaded manually first.
#
# If a CSV file is available through a public URL, pandas can often read it directly.
#
# The basic idea is:
#
# ```text
# URL → read_csv() → DataFrame
# ```
#
# This is different from interacting with a web API.
#
# Here we are simply reading a file available at a URL.

# %% [markdown]
# # Kaggle Data Source – Titanic
#
# For this practical, we will use the famous **Titanic** dataset.
#
# The dataset is part of Kaggle's **Titanic – Machine Learning from Disaster** competition.
#
# A particularly popular Kaggle tutorial is **Titanic Tutorial by Alexis Cook**. It is a beginner-friendly Kaggle notebook with millions of views and uses the Titanic competition data.
#
# ### Useful links
#
# - [Kaggle – Titanic Tutorial by Alexis Cook](https://www.kaggle.com/code/alexisbcook/titanic-tutorial)
# - [Kaggle – Titanic competition and data](https://www.kaggle.com/c/titanic/data)
# - [Kaggle – Titanic notebooks](https://www.kaggle.com/c/titanic/code)
#
# The competition provides `train.csv`, `test.csv` and `gender_submission.csv`. The training data contains passenger information together with the survival outcome.
#
# For Colab, we will also use a public CSV URL containing the same classic Titanic training data so that students can practise URL-based loading without needing a Kaggle login.
#
# **Important:** The Titanic dataset contains missing values. We will only load and inspect the data in this practical. Handling missing values belongs to the later **Data Cleaning and Preparation** practical.

# %% [markdown]
# ## 15. Loading the Titanic data from a URL
#
# The public CSV URL is:
#
# ```text
# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# ```
#
# The file contains 891 passenger records and the familiar Titanic variables such as `PassengerId`, `Survived`, `Pclass`, `Name`, `Sex`, `Age`, `Fare`, `Cabin` and `Embarked`.
#
# ### Live coding
#
# Create a variable called `titanic_url` containing the URL shown above.
#
# Then use pandas to load the URL into a DataFrame called `titanic`.
#
# Finally, display the first five rows.
#
# Write the `read_csv()` command yourself.

# %%
titanic_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
print("Loading Titanic data from a URL:")
# Load the CSV from titanic_url
titanic = pd.read_csv(titanic_url)
# Display the first five rows
print(titanic.head())
# Out:
# Loading Titanic data from a URL:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ## 16. Verify the Titanic data
#
# Before doing anything else, check that the data has loaded correctly.
#
# ### Live coding
#
# Using `titanic`, display:
#
# 1. shape
# 2. column names
# 3. data types
# 4. first five rows

# %%
print("Shape:")
# Write the expression
print(titanic.shape)
print("Columns:")
# Write the expression
print(titanic.columns)
print("Data types:")
# Write the expression
print(titanic.dtypes)
print("First five rows:")
# Write the expression
print(titanic.head())
# Out:
# Shape:
# (891, 12)
# Columns:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Data types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# First five rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# ## 17. Kaggle file path vs Colab URL
#
# When the Titanic dataset is used **inside a Kaggle notebook**, the competition data is normally available through the Kaggle input directory.
#
# A typical Kaggle path for the training file is:
#
# ```text
# /kaggle/input/titanic/train.csv
# ```
#
# In Google Colab, that path normally does not exist.
#
# Instead, we can:
#
# - upload the CSV file to Colab
# - mount Google Drive
# - or read a publicly available CSV URL
#
# This is an important practical difference between notebook environments.
#
# ### Live coding
#
# Write the command that would load:
#
# ```text
# /kaggle/input/titanic/train.csv
# ```
#
# into a DataFrame called `kaggle_titanic`.
#
# You are writing this as a **Kaggle notebook example**; it does not need to be executed in Colab.

# %%
print("Kaggle notebook example:")

# Write the read_csv() command for the Kaggle path
# Out:
# Kaggle notebook example:

# %% [markdown]
# # Part D – Loading a Local File in Google Colab
#
# ## 18. Uploading a file
#
# In Google Colab, a local CSV file can be uploaded from the computer.
#
# The Colab `files` utility provides an upload dialog.
#
# ### Live coding
#
# Write the command that opens the Colab file-upload dialog.
#
# After uploading `train.csv`, the file becomes available in the notebook's working environment.

# %%
# Write the Google Colab upload command here

# %% [markdown]
# ## 19. Loading the uploaded file
#
# After the upload, pandas can read the file using its filename.
#
# ### Live coding
#
# Assume the uploaded file is called `train.csv`.
#
# Load it into a DataFrame called `train_data`.
#
# Display its shape.

# %%
from pathlib import Path

print("Uploaded Titanic file:")
# Create a dummy train.csv file for demonstration
csv_content = "PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked\n1,0,3,\"Braund, Mr. Owen Harris\",male,22,1,0,A/5 21171,7.25,,S\n2,1,1,\"Cumings, Mrs. John Bradley (Florence Briggs Th...\",female,38,1,0,PC 17599,71.2833,C85,C\n"
Path("train.csv").write_text(csv_content)
print("Created dummy train.csv")

# Load train.csv
train_data = pd.read_csv("train.csv")
# Display its shape
print(train_data.shape)
# Out:
# Uploaded Titanic file:
# Created dummy train.csv
# (2, 12)

# %% [markdown]
# ## 20. File path with `pathlib`
#
# Python also provides `pathlib` for working with paths.
#
# A `Path` object can make file paths easier to construct and manage.
#
# ### Live coding
#
# Create a `Path` object for a folder named `data`.
#
# Then create a path for `data/train.csv`.
#
# Display the resulting path.

# %%
from pathlib import Path
# Create the data directory Path
print("Data file path:")
data_path = Path("data")
# Create the path for train.csv
train_path = data_path / "train.csv"
# Display the path
print(train_path)
# Out:
# Data file path:
# data/train.csv

# %% [markdown]
# # Part E – JSON Files
#
# ## 21. Understanding JSON
#
# JSON stands for **JavaScript Object Notation**.
#
# It is a text format commonly used for semi-structured data.
#
# A simple JSON file may look like:
#
# ```json
# [
#     {"Name": "Aman", "Department": "IT", "Salary": 55000},
#     {"Name": "Priya", "Department": "HR", "Salary": 48000}
# ]
# ```
#
# JSON is especially useful when data has a nested or record-based structure.
#
# Pandas provides `read_json()` for many common JSON structures.

# %% [markdown]
# ## 22. Creating a small JSON file
#
# For practice, we will first create a small DataFrame and save it as JSON.
#
# The dataset below is only a practice dataset.
#
# ### Live coding
#
# Run the following setup cell as provided.
#
# Then use pandas to save `employees_demo` as `employees_demo.json`.
#
# The important command is yours to write.

# %%
employees_demo = pd.DataFrame({
    "Employee_ID": ["E101", "E102", "E103", "E104"],
    "Name": ["Aman", "Priya", "Kunal", "Nisha"],
    "Department": ["IT", "HR", "Sales", "IT"],
    "Salary": [55000, 48000, 62000, 59000]
})

print("Practice DataFrame:")
print(employees_demo)
# Out:
# Practice DataFrame:
#   Employee_ID   Name Department  Salary
# 0        E101   Aman         IT   55000
# 1        E102  Priya         HR   48000
# 2        E103  Kunal      Sales   62000
# 3        E104  Nisha         IT   59000

# %% [markdown]
# ## 23. Writing JSON
#
# A DataFrame can be stored as JSON using `.to_json()`.
#
# The `orient` argument controls how the data is represented.
#
# For tabular record-style data, `records` is a useful orientation.
#
# ### Live coding
#
# Save `employees_demo` as:
#
# ```text
# employees_demo.json
# ```
#
# Use record-oriented JSON.
#
# Then confirm that the file has been created.

# %%
print("Saving DataFrame as JSON:")

# Save employees_demo as employees_demo.json
employees_demo.to_json("employees_demo.json")
print("Saved.")
# Out:
# Saving DataFrame as JSON:
# Saved.

# %% [markdown]
# ## 24. Reading JSON
#
# After saving a JSON file, pandas can read it back.
#
# ### Live coding
#
# Read `employees_demo.json` into a DataFrame called `employees_json`.
#
# Display it.

# %%
print("Reading JSON:")
# Read the JSON file
employees_json = pd.read_json("employees_demo.json")
# Display the DataFrame
print(employees_json)
# Out:
# Reading JSON:
#   Employee_ID   Name Department  Salary
# 0        E101   Aman         IT   55000
# 1        E102  Priya         HR   48000
# 2        E103  Kunal      Sales   62000
# 3        E104  Nisha         IT   59000

# %% [markdown]
# ## 25. JSON orientation
#
# Different JSON orientations can represent the same DataFrame in different ways.
#
# Common orientations include:
#
# - `records`
# - `columns`
# - `index`
# - `split`
# - `table`
#
# The correct orientation depends on how the data needs to be stored or exchanged.
#
# For this practical, remember the idea:
#
# > **The same DataFrame can be represented in different JSON structures.**

# %% [markdown]
# # Part F – Excel Files
#
# ## 26. Excel and pandas
#
# Excel files usually have the extension `.xlsx`.
#
# Pandas provides:
#
# - `read_excel()` for reading
# - `to_excel()` for writing
#
# Excel files are common in business environments because people often exchange data through spreadsheets.
#
# ### Live coding
#
# Save `employees_demo` as:
#
# ```text
# employees_demo.xlsx
# ```
#
# Use the default first worksheet.

# %%
print("Saving Excel file:")
# Save employees_demo as an Excel file
employees_demo.to_excel("employees_demo.xlsx")
print("Saved.")
# Out:
# Saving Excel file:
# Saved.

# %% [markdown]
# ## 27. Reading an Excel file
#
# An Excel workbook can contain multiple sheets.
#
# Pandas can read a particular sheet or the first sheet.
#
# ### Live coding
#
# Read the Excel file `employees_demo.xlsx` into `employees_excel`.
#
# Display the DataFrame.

# %%
print("Reading Excel file:")

# Read the Excel file
employees_excel = pd.read_excel("employees_demo.xlsx")
# Display the DataFrame
print(employees_excel)
# Out:
# Reading Excel file:
#    Unnamed: 0 Employee_ID   Name Department  Salary
# 0           0        E101   Aman         IT   55000
# 1           1        E102  Priya         HR   48000
# 2           2        E103  Kunal      Sales   62000
# 3           3        E104  Nisha         IT   59000

# %% [markdown]
# ## 28. Working with sheet names
#
# Suppose an Excel workbook contains:
#
# - `Employees`
# - `Departments`
#
# The `sheet_name` argument can be used to select a particular sheet.
#
# ### Live coding
#
# Write the pandas command that reads the sheet named `Employees` from `company.xlsx`.

# %%
from pathlib import Path
import pandas as pd

print("Loading Excel file with specific sheet:")

# Create a dummy company.xlsx file with an 'Employees' sheet for demonstration
excel_content_df = pd.DataFrame({
    "Name": ["John", "Jane", "Mike"],
    "Department": ["IT", "HR", "Sales"],
    "Salary": [60000, 50000, 65000]
})

with pd.ExcelWriter("company.xlsx") as writer:
    excel_content_df.to_excel(writer, sheet_name="Employees", index=False)

print("Created dummy company.xlsx with 'Employees' sheet")

# Write the read_excel() command here
company_excel = pd.read_excel("company.xlsx",sheet_name="Employees")
print(company_excel)
# Out:
# Loading Excel file with specific sheet:
# Created dummy company.xlsx with 'Employees' sheet
#    Name Department  Salary
# 0  John         IT   60000
# 1  Jane         HR   50000
# 2  Mike      Sales   65000

# %% [markdown]
# # Part G – Writing Tabular Data
#
# ## 29. Saving a DataFrame as CSV
#
# The reverse of `read_csv()` is commonly done using `.to_csv()`.
#
# The general idea is:
#
# ```text
# DataFrame → CSV file
# ```
#
# ### Live coding
#
# Save `employees_demo` as:
#
# ```text
# employees_demo.csv
# ```
#
# Do not save the pandas index as an extra CSV column.
#
# Then read the file back and check its shape.

# %%
print("Saving CSV:")
# Save employees_demo as CSV without the pandas index

# Read the saved CSV
employees_demo.to_csv("employees_demo.csv",index=False)
print("Reading it back:")
emp2 = pd.read_excel("employees_demo.xlsx")
print(emp2)
# Display its shape
# Out:
# Saving CSV:
# Reading it back:
#    Unnamed: 0 Employee_ID   Name Department  Salary
# 0           0        E101   Aman         IT   55000
# 1           1        E102  Priya         HR   48000
# 2           2        E103  Kunal      Sales   62000
# 3           3        E104  Nisha         IT   59000

# %% [markdown]
# ## 30. Saving a DataFrame as a TSV file
#
# A TSV file is simply a text file in which columns are separated by tabs.
#
# ### Live coding
#
# Save `employees_demo` as:
#
# ```text
# employees_demo.tsv
# ```
#
# Use a tab as the separator.
#
# Then read the TSV file back into pandas.

# %%
print("Saving TSV:")
# Save the DataFrame using a tab separator
employees_demo.to_csv("employees_demo.tsv",sep="\t")
print("Reading TSV:")
emp3 = pd.read_csv("employees_demo.tsv",sep="\t")
print(emp3)
# Read the TSV file using the same separator
print(employees_tsv)
# Out:
# Saving TSV:
# Reading TSV:
#    Unnamed: 0 Employee_ID   Name Department  Salary
# 0           0        E101   Aman         IT   55000
# 1           1        E102  Priya         HR   48000
# 2           2        E103  Kunal      Sales   62000
# 3           3        E104  Nisha         IT   59000
#     Name Department  Salary
# 0   Aman         IT   55000
# 1  Priya         HR   48000
# 2  Kunal      Sales   62000

# %% [markdown]
# ## 31. Why specify `index=False`?
#
# A pandas DataFrame has an index.
#
# If we save it directly, the index may also be written to the file.
#
# When the index is only the default `0, 1, 2, ...` and is not meaningful data, we often use:
#
# ```text
# index=False
# ```
#
# This keeps the output file cleaner.
#
# ### Live coding
#
# Save `employees_demo` twice:
#
# 1. once with the default behaviour
# 2. once without writing the index
#
# Compare the two files conceptually.
#
# You do not need to display the entire files.

# %%
# Save with the default index behaviour

# Save again with the index excluded

# %% [markdown]
# # Part H – Binary Storage with Pickle
#
# ## 32. What is a binary format?
#
# Text formats such as CSV and JSON store information as readable text.
#
# Binary formats store information in a form designed for computers rather than direct human reading.
#
# One Python-specific binary format is **Pickle**.
#
# Pandas can save a DataFrame using `.to_pickle()` and load it using `read_pickle()`.
#
# Pickle can preserve Python objects more directly than CSV.
#
# ### Important note
#
# Pickle files should only be loaded from trusted sources. Do not load arbitrary pickle files from unknown websites.

# %% [markdown]
# ## 33. Saving a DataFrame as Pickle
#
# ### Live coding
#
# Save `employees_demo` as:
#
# ```text
# employees_demo.pkl
# ```
#
# Then load it into `employees_pickle`.
#
# Display the loaded DataFrame.

# %%
print("Saving as Pickle:")
# Save employees_demo as a pickle file
employees_demo.to_pickle("employees_demo.pkl")
print("Reading Pickle:")

# Read the pickle file
employees_pickle = pd.read_pickle("employees_demo.pkl")
# Display the loaded DataFrame
print(employees_pickle)
# Out:
# Saving as Pickle:
# Reading Pickle:
#   Employee_ID   Name Department  Salary
# 0        E101   Aman         IT   55000
# 1        E102  Priya         HR   48000
# 2        E103  Kunal      Sales   62000
# 3        E104  Nisha         IT   59000

# %% [markdown]
# ## 34. Comparing CSV and Pickle
#
# Consider the same DataFrame stored as CSV and Pickle.
#
# ### CSV
#
# - text based
# - easy to inspect
# - widely supported
# - good for data exchange
#
# ### Pickle
#
# - binary
# - Python-friendly
# - can preserve Python objects
# - not intended as a universal exchange format
# - should only be loaded from trusted sources
#
# The choice depends on the purpose of the file.

# %% [markdown]
# # Part I – Modern Analytical File Format
#
# ## 35. Parquet
#
# **Parquet** is a column-oriented file format commonly used in data engineering and analytics.
#
# It is designed for efficient storage and reading of tabular data.
#
# Compared with CSV, Parquet can:
#
# - store data types more efficiently
# - support compression
# - read selected columns efficiently
# - work well with large analytical datasets
#
# Pandas can work with Parquet with a suitable engine such as `pyarrow`.
#
# ### Live coding
#
# Save `employees_demo` as `employees_demo.parquet` and read it back.

# %%
# Check whether pyarrow is available.
# If needed, install it in Colab before running the next commands.

print("Parquet practice:")
employees_demo.to_parquet("employees_demo.parquet")
# Save employees_demo as Parquet

# Read employees_demo.parquet back into pandas
employees_parquet = pd.read_parquet("employees_demo.parquet")
print(employees_parquet)
# Out:
# Parquet practice:
#   Employee_ID   Name Department  Salary
# 0        E101   Aman         IT   55000
# 1        E102  Priya         HR   48000
# 2        E103  Kunal      Sales   62000
# 3        E104  Nisha         IT   59000

# %% [markdown]
# # Part J – File Information and Safe Verification
#
# ## 36. Checking whether a file exists
#
# Before trying to read a file, it is useful to check whether the path exists.
#
# `Path.exists()` returns `True` or `False`.
#
# ### Live coding
#
# Check whether `employees_demo.csv` exists.

# %%
from pathlib import Path

print("Does employees_demo.csv exist?")
# Write the Path.exists() expression
Path("employees_demo.csv").exists()
# Out:
# Does employees_demo.csv exist?
# True

# %% [markdown]
# ## 37. Checking file size
#
# A file's size can also be inspected.
#
# `Path.stat().st_size` gives the file size in bytes.
#
# ### Live coding
#
# Display the size of `employees_demo.csv`.

# %%
print("File size in bytes:")
# Write the expression
Path("employees_demo.csv").stat().st_size
# Out:
# File size in bytes:
# 117

# %% [markdown]
# ## 38. Listing generated files
#
# After saving several formats, the working directory may contain:
#
# ```text
# employees_demo.csv
# employees_demo.tsv
# employees_demo.json
# employees_demo.xlsx
# employees_demo.pkl
# ```
#
# ### Live coding
#
# List the files generated in the current directory.

# %%
print("Generated files:")
# Write the expression
list(Path(".").glob("*"))
# Out:
# Generated files:
# [PosixPath('.config'),
#  PosixPath('employees_demo.csv'),
#  PosixPath('employees_demo.json'),
#  PosixPath('employees.tsv'),
#  PosixPath('employees_pipe.txt'),
#  PosixPath('employees_demo.xlsx'),
#  PosixPath('employees_demo.tsv'),
#  PosixPath('employees_demo.parquet'),
#  PosixPath('company.xlsx'),
#  PosixPath('train.csv'),
#  PosixPath('employees_demo.pkl'),
#  PosixPath('employees.csv'),
#  PosixPath('sample_data')]

# %% [markdown]
# # Part K – Guided Practice
#
# ## Question 1 – Load a CSV
#
# Assume `student_marks.csv` is present in the current folder.
#
# Load it into a DataFrame called `marks`.
#
# Display:
#
# 1. shape
# 2. column names
# 3. first five rows

# %%
# Write your solution here
from pathlib import Path

# Create a dummy student_marks.csv file for demonstration
marks_content_df = pd.DataFrame({
    "StudentID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "Marks": [85, 92, 78]
})
Path("student_marks.csv").write_text(marks_content_df.to_csv(index=False))
print("Created dummy student_marks.csv")

student_marks=pd.read_csv("student_marks.csv")
print(student_marks.shape)
print(student_marks.columns)
print(student_marks.head())
# Out:
# Created dummy student_marks.csv
# (3, 3)
# Index(['StudentID', 'Name', 'Marks'], dtype='object')
#    StudentID     Name  Marks
# 0          1    Alice     85
# 1          2      Bob     92
# 2          3  Charlie     78

# %% [markdown]
# ## Question 2 – Load a TSV
#
# A file called `attendance.tsv` uses tabs between columns.
#
# Load it into a DataFrame called `attendance`.
#
# Display its shape and first five rows.

# %%
# Write your solution here
# Load TSV file into a DataFrame
attendance_content_df = pd.DataFrame({
    "StudentID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],})
print(attendance_content_df)
attendance_content_df.to_csv("attendance.tsv", sep="\t", index=False)
# Out:
#    StudentID     Name
# 0          1    Alice
# 1          2      Bob
# 2          3  Charlie

# %% [markdown]
# ## Question 3 – Load a CSV from a URL
#
# Use the Titanic public CSV URL given earlier.
#
# Load it into a DataFrame called `titanic_practice`.
#
# Display its shape.

# %%
# Write your solution here
titanic_practice = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
print(titanic_practice.shape)
# Out:
# (891, 12)

# %% [markdown]
# ## Question 4 – Save a DataFrame
#
# Using `employees_demo`:
#
# 1. save it as CSV
# 2. save it as JSON
# 3. save it as Excel
#
# Use suitable pandas methods.

# %%
# Write your solution here
employees_demo.to_csv("employees_demo.csv",index=False)
employees_demo.to_json("employees_demo.json")
employees_demo.to_excel("employees_demo.xlsx")

# %% [markdown]
# ## Question 5 – Read the saved files
#
# Read the three files created in Question 4 back into:
#
# - `csv_data`
# - `json_data`
# - `excel_data`
#
# Display their shapes.
#
# What do you notice?

# %%
# Write your solution here
csv_data = pd.read_csv("employees_demo.csv")
json_data = pd.read_json("employees_demo.json")
excel_data = pd.read_excel("employees_demo.xlsx")

# %% [markdown]
# ## Question 6 – Local path
#
# Create a `Path` object for:
#
# ```text
# data/employees_demo.csv
# ```
#
# Display it.
#
# Then write the pandas command that could read that file.

# %%
# Write your solution here
from pathlib import Path
import pandas as pd
import shutil

# Create the 'data' directory if it doesn't exist
data_dir = Path("data")
data_dir.mkdir(exist_ok=True)
print(f"Created directory: {data_dir}/")

# Define the source and destination paths
source_file = Path("employees_demo.csv")
destination_file = data_dir / source_file.name

# Copy the file to the new directory (assuming employees_demo.csv exists in the root)
if source_file.exists():
    shutil.copy(source_file, destination_file)
    print(f"Copied {source_file} to {destination_file}")
else:
    print(f"Warning: {source_file} not found for copying. Ensure it was created earlier.")

# Create a Path object for 'data/employees_demo.csv'
file_path = Path("data/employees_demo.csv")

# Display the path
print(f"Generated path: {file_path}")

# Write the pandas command that could read that file
# This command would read the CSV from the specified path
# employees_from_data = pd.read_csv(file_path)
# print(employees_from_data.head())

# For demonstration purposes, only print the command as requested.
# Uncomment the lines above to actually read and display the DataFrame.
print("Pandas command to read this file: pd.read_csv(Path(\"data/employees_demo.csv\"))")
# Out:
# Created directory: data/
# Copied employees_demo.csv to data/employees_demo.csv
# Generated path: data/employees_demo.csv
# Pandas command to read this file: pd.read_csv(Path("data/employees_demo.csv"))

# %% [markdown]
# ## Question 7 – Pickle
#
# Save `employees_demo` as a Pickle file.
#
# Read it back.
#
# Check its type after loading.

# %%
# Write your solution here
employees_demo.to_pickle("employees_demo.pkl")
employees_pickle = pd.read_pickle("employees_demo.pkl")
print(type(employees_pickle))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Part L – Case Study: Preparing a Data File for a Data Science Team
#
# ## Business situation
#
# A data science team is starting a project using passenger data from the **Titanic – Machine Learning from Disaster** competition.
#
# The team has received data in different ways:
#
# - a public CSV URL
# - a downloaded Kaggle CSV file
# - a small Excel file from an analyst
# - a JSON file used by another application
# - a Python Pickle file used by an internal notebook
#
# Your job is to load the available data, inspect the files, and save useful copies in appropriate formats.
#
# The focus is **data loading, storage and file formats**.
#
# Do not perform data cleaning, merging, visualization, aggregation, API calls or time-series analysis in this case study.

# %% [markdown]
# ## Case Study – Data Source
#
# The main dataset is the Titanic training data.
#
# Use these references:
#
# - [Popular Kaggle notebook – Titanic Tutorial by Alexis Cook](https://www.kaggle.com/code/alexisbcook/titanic-tutorial)
# - [Kaggle Titanic competition data](https://www.kaggle.com/c/titanic/data)
# - [Public CSV copy for Colab](https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv)
#
# The Kaggle competition describes the training data as the dataset containing the known survival outcome, while the test data does not contain the survival outcome.
#
# For this practical, we are interested in **loading and storing the data**, not building a prediction model.

# %% [markdown]
# ## Question 8 – Load the main dataset
#
# Load the Titanic CSV from the public URL into a DataFrame called `titanic`.
#
# Display:
#
# 1. the first five rows
# 2. shape
# 3. column names

# %%
# Write your solution here
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
print(titanic.head())
print(titanic.shape)
print(titanic.columns)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# ## Question 9 – Confirm the data type
#
# Check the type of `titanic`.
#
# Then check the data type of:
#
# ```text
# titanic["Age"]
# ```
#
# Do not clean or transform the column.

# %%
# Write your solution here
print(type(titanic))
print(type(titanic["Age"]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Question 10 – Load only selected columns
#
# The data science team wants a smaller file containing only:
#
# - PassengerId
# - Survived
# - Pclass
# - Sex
# - Age
# - Fare
#
# Load only these columns directly from the CSV URL into `titanic_basic`.
#
# Do not load the complete dataset first and then remove columns.

# %%
# Write your solution here
titanic_basic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=["PassengerId", "Survived", "Pclass", "Sex", "Age", "Fare"])

# %% [markdown]
# ## Question 11 – Load a limited sample
#
# Before processing the full file, an analyst wants to test the notebook using only the first 10 records.
#
# Load the first 10 rows from the Titanic URL into `titanic_sample`.
#
# Display the result.

# %%
# Write your solution here
titanic_sample = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", nrows=10)
print(titanic_sample)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ## Question 12 – Save a working CSV copy
#
# The team wants a local copy of the full Titanic data.
#
# Save `titanic` as:
#
# ```text
# titanic_working.csv
# ```
#
# Do not write the pandas index into the file.

# %%
# Write your solution here
titanic.to_csv("titanic_working.csv", index=False)

# %% [markdown]
# ## Question 13 – Read the saved CSV
#
# Read `titanic_working.csv` back into a DataFrame called `titanic_csv`.
#
# Check:
#
# - shape
# - column names
#
# The result should represent the same tabular data that was saved.

# %%
# Write your solution here
titanic_csv = pd.read_csv("titanic_working.csv")
print(titanic_csv.shape)
print(titanic_csv.columns)
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Question 14 – Create a JSON copy
#
# The application team wants a record-oriented JSON version of the data.
#
# Save `titanic` as:
#
# ```text
# titanic_records.json
# ```
#
# Use a JSON orientation suitable for a collection of records.

# %%
# Write your solution here
titanic.to_json("titanic_records.json", orient="records")

# %% [markdown]
# ## Question 15 – Read the JSON copy
#
# Read `titanic_records.json` back into a DataFrame called `titanic_json`.
#
# Display:
#
# - shape
# - first five rows

# %%
# Write your solution here
titanic_json = pd.read_json("titanic_records.json")
print(titanic_json.shape)
print(titanic_json.head())
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500  None        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  None        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ## Question 16 – Create an Excel copy
#
# A business analyst wants to open the dataset in Excel.
#
# Save the Titanic DataFrame as:
#
# ```text
# titanic_working.xlsx
# ```
#
# Do not perform any cleaning or analysis before saving it.

# %%
# Write your solution here
titanic.to_excel("titanic_working.xlsx", index=False)

# %% [markdown]
# ## Question 17 – Read the Excel copy
#
# Read `titanic_working.xlsx` into `titanic_excel`.
#
# Display:
#
# - shape
# - first five rows

# %%
# Write your solution here
titanic_excel = pd.read_excel("titanic_working.xlsx")
print(titanic_excel.shape)
print(titanic_excel.head())
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ## Question 18 – Save a Python-friendly copy
#
# The internal data science team wants a Python-friendly copy that can be loaded back as a pandas object.
#
# Save the dataset as:
#
# ```text
# titanic_working.pkl
# ```
#
# Then read it back into `titanic_pickle`.
#
# Check its type and shape.

# %%
# Write your solution here
titanic.to_pickle("titanic_working.pkl")
titanic_pickle = pd.read_pickle("titanic_working.pkl")
print(type(titanic_pickle))
print(titanic_pickle.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (891, 12)

# %% [markdown]
# ## Question 19 – Compare file formats
#
# The team now has:
#
# - `titanic_working.csv`
# - `titanic_records.json`
# - `titanic_working.xlsx`
# - `titanic_working.pkl`
#
# For each file, decide which situation it is most suitable for:
#
# ### Situation A
# The file must be easily opened by a person using a spreadsheet application.
#
# ### Situation B
# The file needs to be shared with many different programming languages and tools as simple tabular text.
#
# ### Situation C
# The file is mainly for reuse inside a Python-based analysis workflow.
#
# ### Situation D
# The receiving application expects record-style structured data.
#
# Write the format you would choose for each situation in a Python comment.

# %%
# Write your answers as comments.

# %% [markdown]
# ## Question 20 – Verify the saved files
#
# Use `pathlib` to check whether these files exist:
#
# - `titanic_working.csv`
# - `titanic_records.json`
# - `titanic_working.xlsx`
# - `titanic_working.pkl`
#
# Display the result for each file.

# %%
# Write your solution here
from pathlib import Path

# %% [markdown]
# ## Question 21 – Inspect file sizes
#
# Use `pathlib` to display the size in bytes of:
#
# - `titanic_working.csv`
# - `titanic_records.json`
# - `titanic_working.xlsx`
# - `titanic_working.pkl`
#
# Do not assume that the largest file is the "best" file.
#
# Think about the purpose of each format.

# %%
# Write your solution here

# %% [markdown]
# ## Question 22 – Create a compact CSV file
#
# The team wants a lightweight CSV containing only:
#
# - PassengerId
# - Survived
# - Pclass
# - Sex
# - Age
# - Fare
#
# Load these columns directly from the source URL and save them as:
#
# ```text
# titanic_basic.csv
# ```
#
# Do this without first saving the full dataset and then deleting columns.

# %%
# Write your solution here
titanic_basic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=["PassengerId", "Survived", "Pclass", "Sex", "Age", "Fare"])

# %% [markdown]
# ## Question 23 – Create a small test file
#
# Before sending the data to another analyst, the team wants a small test file containing only the first 20 records.
#
# Create:
#
# ```text
# titanic_sample.csv
# ```
#
# It should contain the first 20 rows of the original Titanic data.
#
# Do not manually copy the records.

# %%
# Write your solution here
titanic_sample = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", nrows=20)
titanic_sample.to_csv("titanic_sample.csv", index=False)

# %% [markdown]
# ## Question 24 – Load the test file
#
# Read `titanic_sample.csv` back into pandas.
#
# Check:
#
# 1. shape
# 2. first five rows
# 3. column names
#
# This is a final check that the save-and-load cycle worked correctly.

# %%
# Write your solution here
titanic_sample = pd.read_csv("titanic_sample.csv")
print(titanic_sample.shape)
print(titanic_sample.head())
print(titanic_sample.columns)
# Out:
# (20, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# # Final Case Study Challenge
#
# ## Question 25 – Choose the right storage format
#
# The project manager gives you four requirements.
#
# ### Requirement 1
# A university teacher wants to open the data manually in Microsoft Excel and review it.
#
# ### Requirement 2
# A data scientist wants a simple file that can be shared through email and opened by many tools.
#
# ### Requirement 3
# A Python team wants to save and reload a pandas object inside its own trusted workflow.
#
# ### Requirement 4
# A software application needs structured records that can easily be exchanged with other systems.
#
# For each requirement:
#
# 1. choose a suitable format
# 2. write the pandas command that would save the `titanic` DataFrame in that format
# 3. mention one reason for your choice in a Python comment
#
# Do not actually create another copy if you have already created the same format earlier; the purpose here is to demonstrate that you know which command and format belong to each requirement.

# %%
# Requirement 1
# Write your answer and command.

# Requirement 2
# Write your answer and command.

# Requirement 3
# Write your answer and command.

# Requirement 4
# Write your answer and command.

# %% [markdown]
# # Quick Check Before You Finish
#
# Make sure you have practised these ideas:
#
# ### Loading data
#
# - `pd.read_csv()`
# - reading a CSV from a local path
# - reading a CSV from a URL
# - reading a file with a different separator
# - reading TSV data
# - selecting columns while loading
# - limiting rows while loading
# - `pd.read_json()`
# - `pd.read_excel()`
# - `pd.read_pickle()`
#
# ### Saving data
#
# - `DataFrame.to_csv()`
# - `DataFrame.to_json()`
# - `DataFrame.to_excel()`
# - `DataFrame.to_pickle()`
#
# ### File and path handling
#
# - current working directory
# - listing files
# - `Path`
# - `Path.exists()`
# - file size using `Path.stat().st_size`
#
# ### File formats
#
# - CSV
# - TSV / delimited text
# - JSON
# - Excel
# - Pickle
# - Parquet concept
#
# ### Important distinction
#
# This practical is about **getting data into pandas and storing it appropriately**.
#
# It is not yet about:
#
# - cleaning missing data
# - transforming messy data
# - combining datasets
# - reshaping data
# - plotting
# - grouping and aggregation
# - web APIs
# - time-series analysis
#
# Those topics can be applied later after the data has been loaded successfully.
#
# > **A good data analysis workflow starts by knowing where the data comes from, how it is stored, how to load it correctly, and how to save it in a form that other people and tools can use.**
